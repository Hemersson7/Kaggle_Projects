# %% [markdown]
# ### Importacion de librerias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import janitor
################
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
################

# %% [markdown]
# ### Carga de datos

# %%
df = pd.read_csv("precio_mayorista_fruta-hortaliza_2025.csv")
df = df.clean_names()
df.head()
# Out:
#         fecha  id_region                region  \
# 0  2025-01-02          5  Región de Valparaíso
# 1  2025-01-02          8     Región del Biobío
# 2  2025-01-02         16       Región de Ñuble
# 3  2025-01-02         16       Región de Ñuble
# 4  2025-01-02          4    Región de Coquimbo
#
#                                 mercado                subsector producto  \
# 0                  Femacal de La Calera  Hortalizas y tubérculos   Acelga
# 1            Vega Monumental Concepción  Hortalizas y tubérculos   Acelga
# 2  Terminal Hortofrutícola Agro Chillán  Hortalizas y tubérculos   Acelga
# 3  Terminal Hortofrutícola Agro Chillán  Hortalizas y tubérculos   Acelga
# 4      Terminal La Palmera de La Serena  Hortalizas y tubérculos      Ají
#
#      variedad_tipo  calidad    unidad_de_comercializacion  \
# 0  Sin especificar  Primera  $/docena de atados (6 kilos)
# 1  Sin especificar  Primera          $/atado 0,5 a 1 kilo
# ...

# %% [markdown]
# ### Analisis descriptivo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113511 entries, 0 to 113510
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Fecha                       113511 non-null  object
#  1   ID region                   113511 non-null  int64
#  2   Region                      113511 non-null  object
#  3   Mercado                     113511 non-null  object
#  4   Subsector                   113511 non-null  object
#  5   Producto                    113511 non-null  object
#  6   Variedad / Tipo             113511 non-null  object
#  7   Calidad                     113511 non-null  object
#  8   Unidad de comercializacion  113511 non-null  object
#  9   Origen                      113511 non-null  object
#  10  Volumen                     113511 non-null  int64
#  11  Precio minimo               113511 non-null  object
#  12  Precio maximo               113511 non-null  object
# ...

# %%
df.nunique()
# Out:
# Fecha                           137
# ID region                         9
# Region                            9
# Mercado                          12
# Subsector                         2
# Producto                         81
# Variedad / Tipo                 222
# Calidad                          48
# Unidad de comercializacion      143
# Origen                           61
# Volumen                        1302
# Precio minimo                   332
# Precio maximo                   287
# Precio promedio ponderado     11209
# dtype: int64

# %%
df.describe(include= "all").T
# Out:
#                                count unique  \
# Fecha                         113511    137
# ID region                   113511.0    NaN
# Region                        113511      9
# Mercado                       113511     12
# Subsector                     113511      2
# Producto                      113511     81
# Variedad / Tipo               113511    222
# Calidad                       113511     48
# Unidad de comercializacion    113511    143
# Origen                        113511     61
# Volumen                     113511.0    NaN
# Precio minimo                 113511    332
# Precio maximo                 113511    287
# Precio promedio ponderado     113511  11209
#
#                                                                   top   freq  \
# Fecha                                                      2025-02-11   1009
# ID region                                                         NaN    NaN
# ...

# %%
df.head()
# Out:
#         Fecha  ID region                Region  \
# 0  2025-01-02          5  Región de Valparaíso
# 1  2025-01-02          8     Región del Biobío
# 2  2025-01-02         16       Región de Ñuble
# 3  2025-01-02         16       Región de Ñuble
# 4  2025-01-02          4    Región de Coquimbo
#
#                                 Mercado                Subsector Producto  \
# 0                  Femacal de La Calera  Hortalizas y tubérculos   Acelga
# 1            Vega Monumental Concepción  Hortalizas y tubérculos   Acelga
# 2  Terminal Hortofrutícola Agro Chillán  Hortalizas y tubérculos   Acelga
# 3  Terminal Hortofrutícola Agro Chillán  Hortalizas y tubérculos   Acelga
# 4      Terminal La Palmera de La Serena  Hortalizas y tubérculos      Ají
#
#    Variedad / Tipo  Calidad    Unidad de comercializacion  \
# 0  Sin especificar  Primera  $/docena de atados (6 kilos)
# 1  Sin especificar  Primera          $/atado 0,5 a 1 kilo
# ...

# %%
df.columns
# Out:
# Index(['Fecha', 'ID region', 'Region', 'Mercado', 'Subsector', 'Producto',
#        'Variedad / Tipo', 'Calidad', 'Unidad de comercializacion', 'Origen',
#        'Volumen', 'Precio minimo', 'Precio maximo',
#        'Precio promedio ponderado'],
#       dtype='object')

# %%
df.head(5)
# Out:
#         fecha  id_region                region  \
# 0  2025-01-02          5  Región de Valparaíso
# 1  2025-01-02          8     Región del Biobío
# 2  2025-01-02         16       Región de Ñuble
# 3  2025-01-02         16       Región de Ñuble
# 4  2025-01-02          4    Región de Coquimbo
#
#                                 mercado                subsector producto  \
# 0                  Femacal de La Calera  Hortalizas y tubérculos   Acelga
# 1            Vega Monumental Concepción  Hortalizas y tubérculos   Acelga
# 2  Terminal Hortofrutícola Agro Chillán  Hortalizas y tubérculos   Acelga
# 3  Terminal Hortofrutícola Agro Chillán  Hortalizas y tubérculos   Acelga
# 4      Terminal La Palmera de La Serena  Hortalizas y tubérculos      Ají
#
#      variedad_tipo  calidad    unidad_de_comercializacion  \
# 0  Sin especificar  Primera  $/docena de atados (6 kilos)
# 1  Sin especificar  Primera          $/atado 0,5 a 1 kilo
# ...

# %%
var_num = ['volumen', 'precio_minimo', 'precio_maximo', 'precio_promedio_ponderado']
df[var_num] = df[var_num].replace(',', '.', regex = True).astype(float).round(0).astype('Int64')
df["fecha"] = pd.to_datetime(df["fecha"],format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113511 entries, 0 to 113510
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   fecha                       113511 non-null  datetime64[ns]
#  1   id_region                   113511 non-null  int64
#  2   region                      113511 non-null  object
#  3   mercado                     113511 non-null  object
#  4   subsector                   113511 non-null  object
#  5   producto                    113511 non-null  object
#  6   variedad_tipo               113511 non-null  object
#  7   calidad                     113511 non-null  object
#  8   unidad_de_comercializacion  113511 non-null  object
#  9   origen                      113511 non-null  object
#  10  volumen                     113511 non-null  Int64
#  11  precio_minimo               113511 non-null  Int64
# ...

# %%
df[['volumen', 'precio_minimo', 'precio_maximo', 'precio_promedio_ponderado', 'producto']]
# Out:
#         volumen  precio_minimo  precio_maximo  precio_promedio_ponderado  \
# 0           110           4000           4000                       4000
# 1           300            800            800                        800
# 2           200            600            600                        600
# 3           600            500            500                        500
# 4           400          15000          17000                      16000
# ...         ...            ...            ...                        ...
# 113506      520           5000           5200                       5100
# 113507      900           5000           5000                       5000
# 113508      340           4000           4500                       4250
# 113509      600           4500           4500                       4500
# 113510      500           3800           3800                       3800
#
#         producto
# 0         Acelga
# 1         Acelga
# 2         Acelga
# 3         Acelga
# ...
